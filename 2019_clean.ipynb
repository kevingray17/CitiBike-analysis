# %%
import pandas as pd
import glob

# %%
bike_data = bike_data = pd.concat([pd.read_csv(f) for f in glob.glob('2019_data/*.csv')], ignore_index = True)

# %%
bike_data.head(2500000)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                  88  2019-04-01 00:00:14.7410  2019-04-01 00:01:42.8900
# 1                 443  2019-04-01 00:00:20.8270  2019-04-01 00:07:44.2920
# 2                 662  2019-04-01 00:00:30.9960  2019-04-01 00:11:33.2610
# 3                  86  2019-04-01 00:00:30.9110  2019-04-01 00:01:56.9600
# 4                 136  2019-04-01 00:00:32.5930  2019-04-01 00:02:49.3910
# ...               ...                       ...                       ...
# 2499995          2044  2019-03-19 18:12:49.1580  2019-03-19 18:46:53.6940
# 2499996          1109  2019-03-19 18:12:47.2510  2019-03-19 18:31:17.1990
# 2499997           188  2019-03-19 18:12:55.5230  2019-03-19 18:16:03.6130
# 2499998           290  2019-03-19 18:12:47.2000  2019-03-19 18:17:37.3710
# 2499999           504  2019-03-19 18:12:53.0600  2019-03-19 18:21:17.1020
#
#          start station id      start station name  start station latitude  \
# ...

# %%
bike_data.count()
# Out:
# tripduration               5018617
# starttime                  5018617
# stoptime                   5018617
# start station id           5018607
# start station name         5018607
# start station latitude     5018617
# start station longitude    5018617
# end station id             5018607
# end station name           5018607
# end station latitude       5018617
# end station longitude      5018617
# bikeid                     5018617
# usertype                   5018617
# birth year                 5018617
# gender                     5018617
# dtype: int64

# %%
first_data_csv = bike_data. to_csv('first_data.csv', index = True)
print('\nCSV String:\n', first_data_csv)
# Out:
# CSV String:
#  None
