# %%
import pandas as pd
import glob

# %%
more_bike_data = bike_data = pd.concat([pd.read_csv(f) for f in glob.glob('2020_data/*.csv')], ignore_index = True)

# %%
more_bike_data.head(2000000)
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1                 529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2                1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3                 341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4                2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
# ...               ...                       ...                       ...
# 1999995          1373  2020-05-07 08:04:15.5880  2020-05-07 08:27:09.4200
# 1999996          1046  2020-05-07 08:04:16.2550  2020-05-07 08:21:42.6020
# 1999997          1267  2020-05-07 08:04:22.3040  2020-05-07 08:25:30.0780
# 1999998           194  2020-05-07 08:04:27.1060  2020-05-07 08:07:41.6700
# 1999999           223  2020-05-07 08:04:27.9670  2020-05-07 08:08:11.9220
#
#          start station id                  start station name  \
# ...

# %%
more_bike_data.count()
# Out:
# tripduration               3239109
# starttime                  3239109
# stoptime                   3239109
# start station id           3239109
# start station name         3239109
# start station latitude     3239109
# start station longitude    3239109
# end station id             3239109
# end station name           3239109
# end station latitude       3239109
# end station longitude      3239109
# bikeid                     3239109
# usertype                   3239109
# birth year                 3239109
# gender                     3239109
# dtype: int64

# %%
second_data_csv = more_bike_data. to_csv('second_data.csv', index = True)
print('\nCSV String:\n', second_data_csv)
# Out:
# CSV String:
#  None
